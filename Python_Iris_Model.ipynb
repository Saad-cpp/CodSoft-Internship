# %% [markdown]
# <a href="https://colab.research.google.com/github/Saad-cpp/CodSoft-Internship/blob/main/Python_Iris_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset = pd.read_csv("https://raw.githubusercontent.com/amankharwal/Website-data/master/IRIS.csv")

# %%
dataset.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
Y = dataset['species']
X = dataset.drop('species', axis=1)

# %%
X.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
Y.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: species, dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2)

# %%
model = RandomForestClassifier()
myModel = model.fit(X_train,Y_train)

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(Y_test,predictions)
print(score*100,"% accurate")
# Out:
# 96.66666666666667 % accurate
